561,0.7479438247161441,-0.02337585004455498,-0.7209002181417112,-0.6042664041381788,0.7729114863858737,0.1299050964882918,1.892190762917969,0.7775262337466157,1.153211415706021,-0.06712096716101633,-0.7159605359663685,0.5745103027717882,-0.5332488252300612],"y":[0.48565369320008445,0.12041424736418813,0.3728548594600659,0.7712753870061477,-0.4694799594082128,-0.9329257915017762,1.6042850066405474,0.9535198254951228,-0.6992901204714602,-0.214701353800161,0.21537033389134091,0.22476401860268208,0.21732126353567846,1.784386546692405,0.8386897583666759,-1.4561903519161725,-0.6303661119832508,0.5415348552478733,-0.012776030914644024,0.36797913082990846,-0.8411391663215008,0.3616929145737836,-1.264320330207798,-0.26502269157193953,1.3863386702655478,-0.7248415367178042,-0.2178092018139054,-0.24459985857236982,0.19608088388729106,-0.8384209751912628,-0.03148895043489578,-1.5088891201643704,0.5496834805194253,0.8239104224722363,1.2250713958297823,0.5833910287006718,-0.652529020663938,0.2502087888793457,-0.31570771883517285,0.4625327294010034,-0.7772963400716304,0.15260396510774513,1.8407107256417161,-0.41702060196958535,0.1419693760465544,0.7294536725795334,0.04338978784559863,-0.8438506356889561,0.3091430311742467,-0.026665341694522168,-1.3344843758719684,1.4148579535365777,0.40964365364180094,0.3305268076716697,1.7259831820461027,0.39661446244501775,0.3797142977688465,0.2729619200341809,0.8332516361210731,-1.2370597375124273,-0.4688379664592874,0.724464869087 ...

# %%
lr.coef_
# Out:
# array([16.51994636, 24.5810567 ])

# %%
lr.intercept_
# Out:
# np.float64(2.944462048304633)

# %% [markdown]
# Creating Multiple Linear Regression Class

# %%
from sklearn.datasets import load_diabetes
x,y = load_diabetes(return_X_y = True)

# %%
x
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
x.shape
# Out:
# (442, 10)

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#         60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#        197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#         59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#        237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#        143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#        142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#         77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#         78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#        154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#         71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#        150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#        145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#         94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#         60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#         31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#        114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#        191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#        244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#        263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#         77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#         58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#        140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#        219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#         43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#        140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#         84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#         94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#        220.,  57.])

# %%
y.shape
# Out:
# (442,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 2)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (353, 10)
# (89, 10)

# %%
reg = LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4399338661568968

# %%
reg.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
reg.intercept_
# Out:
# np.float64(151.88331005254167)

# %%
class MLR:
  def __init__(self):
    self.coef_ = None
    self.intercept_ = None

  def fit(self, x_train, y_train):
    # Add a bias (intercept) term to x_train
    X_b = np.insert(x_train, 0, 1, axis = 1)

    # Calculate betas using the normal equation: (X_b.T @ X_b)^-1 @ X_b.T @ y
    betas = np.linalg.inv(np.dot(X_b.T, X_b)).dot(X_b.T).dot(y_train)

    self.intercept_ = betas[0]
    self.coef_ = betas[1:]

  def predict(self, x_test):
    # Ensure x_test aligns with coef_ for multiplication and then add intercept
    return np.dot(x_test, self.coef_) + self.intercept_

# %%
lr = MLR()

# %%
lr.fit(x_train, y_train)

# %%
x_train.shape
# Out:
# (353, 10)

# %%
np.insert(x_train, 0 ,1, axis = 1).shape
# Out:
# (353, 11)

# %%
y_pred = lr.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.43993386615689634

# %%
lr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
lr.intercept_
# Out:
# np.float64(151.88331005254165)
